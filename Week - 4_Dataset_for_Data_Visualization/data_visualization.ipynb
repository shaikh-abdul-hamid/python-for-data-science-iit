# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
cars_data=pd.read_csv("Toyota.csv", index_col=0, na_values=["??","????"])

# %%
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 10 columns]

# %% [markdown]
# # removing misisng values

# %%
cars_data.dropna(axis=0, inplace=True)

# %%
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5     12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1423   7950  80.0  35821.0   Petrol   86.0       0.0          1  1300      3
# 1424   7750  73.0  34717.0   Petrol   86.0       0.0          0  1300      3
# 1429   8950  78.0  24000.0   Petrol   86.0       1.0          1  1300      5
# 1430   8450  80.0  23000.0   Petrol   86.0       0.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 3       1165
# 4       1170
# 5       1170
# ...      ...
# 1423    1015
# 1424    1015
# 1429    1065
# 1430    1015
# 1435    1114
#
# [1096 rows x 10 columns]

# %%
plt.scatter(cars_data["Age"], cars_data["Price"],c='red')
plt.title("Age vs Price")
plt.xlabel("Age")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# price of the car decreases as age of the car increases

# %% [markdown]
# # Histogram

# %% [markdown]
# What is a histogram?
#
# · It is a graphical representation of data using
# bars of different heights
#
# · Histogram groups numbers into ranges and
# the height of each bar depicts the frequency
# of each range or bin
#
#
# When to use histograms?
#
# · To represent the frequency distribution of
# numeical variables

# %%
plt.hist(cars_data["KM"],color = "green", edgecolor = "white", bins = 5)
plt.title("Histogram of KM")
plt.xlabel("KM")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Frequency distribution of kilometre of the cars shows that
# most of the cars have travelled between 50000 – 100000 km
# and there are only few cars with more distance travelled

# %% [markdown]
# # bar plot

# %% [markdown]
# What is a bar plot?
#
# • A bar plot is a plot that presents categorical
# data with rectangular bars with lengths
# proportional to the counts that they
# represent
#
# When to use bar plot?
#
# • To represent the frequency distribution of
# categorical variables
#
# • A bar diagram makes it easy to compare sets
# of data between different groups

# %%
counts = cars_data["FuelType"].value_counts()
index=np.arange(len(counts.index))
plt.bar(counts.index, counts.values, color=['blue', 'red', 'green'])
plt.title("Bar Plot of Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn is a Python data visualization library
# based on matplotlib
#
# • It provides a high-level interface for drawing
# attractive and informative statistical graphics

# %%
import seaborn as sns

# %% [markdown]
# # scatter plot

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars_data["Age"], y=cars_data["Price"]
            )
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %% [markdown]
# By default, fit_reg = True
#
# It estimates and plots a regression
# model relating the x and y variables

# %%
sns.regplot(x=cars_data["Age"], y=cars_data["Price"], fit_reg=False)
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
sns.regplot(x=cars_data['Age'], y=cars_data['Price'], marker='*', fit_reg=False)
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %% [markdown]
# Using hue parameter, including another variable to show the fuel
# types categories with different colors

# %%
sns.lmplot(x="Age",y="Price", data=cars_data,fit_reg=False, hue="FuelType", legend=True, palette="Set1")

# %% [markdown]
# # histogram

# %%
sns.distplot(cars_data["Age"])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27808\661506049.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(
    cars_data["Age"], kde=True,
    stat="density", kde_kws=dict(cut=3)
)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(
    cars_data["Age"], kde=False,
    stat="density", kde_kws=dict(cut=3), bins=5
)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Barplot

# %%
sns.countplot(x="FuelType", data=cars_data, palette="Set1")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27808\1515860404.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="FuelType", data=cars_data, palette="Set1")
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
sns.countplot(x="FuelType", data=cars_data, palette="Set1")

# %%
sns.barplot(x="FuelType", y="Price", data=cars_data, palette="Set1", hue="Automatic")
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %% [markdown]
# # Box and whiskers plot – numerical variable

# %% [markdown]
# Box and whiskers plot of Price to visually interpret the
# five-number summary

# %%
sns.boxplot(y=cars_data["Price"])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.boxplot(x=cars_data["FuelType"], y=cars_data["Price"])
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x=cars_data["FuelType"], y=cars_data["Price"], hue="Automatic" ,data=cars_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %% [markdown]
# # Box-whiskers plot and Histogram

# %%
f, (ax_box,ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# %%
f, (ax_box,ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(cars_data["Price"], ax=ax_box, color="blue", fliersize=0,)
sns.distplot(cars_data["Price"], ax=ax_hist, color="blue", kde=False)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27808\3494107254.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data["Price"], ax=ax_hist, color="blue", kde=False)
# <Axes: xlabel='Price'>

# %% [markdown]
# # Pairwise plots
#
#  It is used to plot pairwise relationships in a dataset
#
#  Creates scatterplots for joint relationships and histograms for
# univariate distributions

# %%
sns.pairplot(cars_data, kind="scatter", hue="FuelType")
plt.show()
